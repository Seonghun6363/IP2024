# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('view5.png')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
sift = cv2.SIFT_create()
kp, des= sift.detectAndCompute(gray,None)
img=cv2.drawKeypoints(gray, kp, img)
cv2.imwrite('sift_view5.png', img)
# Out:
# True

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img1 = cv2.imread('view1.png',0) # queryImage
img2 = cv2.imread('view5.png',0) # trainImage

sift = cv2.SIFT_create()
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)

# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
# Match descriptors.
matcher = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)
matches = matcher.match(des1, des2)
# Sort them in the order of their distance.

matches = sorted(matches, key = lambda x:x.distance)
# Draw first 10 matches.
img3 = cv2.drawMatches(img1,kp1,img2,kp2, matches, None, \
    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x26c002e4760>, None)

# %%
img1 = cv2.imread('bike.png',0)
# queryImage
img2 = cv2.imread('bike1.png',0) # trainImage
# Initiate SIFT detector
orb = cv2.ORB()
# find the keypoints and descriptors with SIFT
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)
# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
# Match descriptors.
matches = bf.match(des1,des2)
# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)
 # Draw first 10 matches.
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10], flags=2)
plt.imshow(img3),plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[22], line 7
#       5 orb = cv2.ORB()
#       6 # find the keypoints and descriptors with SIFT
# ----> 7 kp1, des1 = orb.detectAndCompute(img1,None)
#       8 kp2, des2 = orb.detectAndCompute(img2,None)
#       9 # create BFMatcher object
#
# error: Unknown C++ exception from OpenCV code
